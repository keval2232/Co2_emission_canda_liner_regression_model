# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import  train_test_split
from sklearn import preprocessing

# %% [markdown]
# # initilize parameters

# %%
def initilize_parameters(x,y):
    m=x.shape[0]
    #a=np.ones((m,1))
    #x.insert(0,"onces",a)
    #theta=np.zeros((x.shape[1],1))
    theta = np.random.randn(x.shape[1],1)
    return theta

# %% [markdown]
# # computer cost

# %%
def compute_cost(x,y,theta):
    m=x.shape[0]
    J=0
    predcitons=predict(x,theta)
    squareError = np.power(predcitons-y,2)
    J=(1/2*m)*(np.sum(squareError))
    return J

# %% [markdown]
# #  predictions

# %%
def predict(x,theta):
    predictions = np.dot(x,theta)
    return predictions

# %% [markdown]
# #  Gradient desent

# %%
def gradientDesent(x,y,alpha,num_inters):
    theta=initilize_parameters(x,y)
    J_history=np.zeros((num_inters,1))
    m=x.shape[0]
    for i in range(1,num_inters+1):
        error = np.dot(x,theta)-y;
        theta= theta-((alpha/m)*(np.dot(x.T,error)))
        #print(error.shape)
        #print(theta.shape)
        #print((np.dot(x.T,error)).shape)
        if i%100==0:
            print(compute_cost(x,y,theta))

        J_history = compute_cost(x, y, theta)
    return theta

# %%
data=pd.read_csv('CO2 Emissions_Canada.csv')
data.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
data['Fuel Type'].unique()
# Out:
# array(['Z', 'D', 'X', 'E', 'N'], dtype=object)

# %%
data['Vehicle Class'].unique()
# Out:
# array(['COMPACT', 'SUV - SMALL', 'MID-SIZE', 'TWO-SEATER', 'MINICOMPACT',
#        'SUBCOMPACT', 'FULL-SIZE', 'STATION WAGON - SMALL',
#        'SUV - STANDARD', 'VAN - CARGO', 'VAN - PASSENGER',
#        'PICKUP TRUCK - STANDARD', 'MINIVAN', 'SPECIAL PURPOSE VEHICLE',
#        'STATION WAGON - MID-SIZE', 'PICKUP TRUCK - SMALL'], dtype=object)

# %%
data['Transmission'].unique()
# Out:
# array(['AS5', 'M6', 'AV7', 'AS6', 'AM6', 'A6', 'AM7', 'AV8', 'AS8', 'A7',
#        'A8', 'M7', 'A4', 'M5', 'AV', 'A5', 'AS7', 'A9', 'AS9', 'AV6',
#        'AS4', 'AM5', 'AM8', 'AM9', 'AS10', 'A10', 'AV10'], dtype=object)

# %%
data['Make'].unique()
# Out:
# array(['ACURA', 'ALFA ROMEO', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW',
#        'BUICK', 'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DODGE', 'FIAT',
#        'FORD', 'GMC', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP',
#        'KIA', 'LAMBORGHINI', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'MASERATI',
#        'MAZDA', 'MERCEDES-BENZ', 'MINI', 'MITSUBISHI', 'NISSAN',
#        'PORSCHE', 'RAM', 'ROLLS-ROYCE', 'SCION', 'SMART', 'SRT', 'SUBARU',
#        'TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'GENESIS', 'BUGATTI'],
#       dtype=object)

# %%
x=data[['Make','Vehicle Class', 'Engine Size(L)', 'Cylinders',
       'Transmission', 'Fuel Type','Fuel Consumption Comb (L/100 km)',
       'Fuel Consumption Comb (mpg)']]

x.head()
# Out:
#     Make Vehicle Class  Engine Size(L)  Cylinders Transmission Fuel Type  \
# 0  ACURA       COMPACT             2.0          4          AS5         Z
# 1  ACURA       COMPACT             2.4          4           M6         Z
# 2  ACURA       COMPACT             1.5          4          AV7         Z
# 3  ACURA   SUV - SMALL             3.5          6          AS6         Z
# 4  ACURA   SUV - SMALL             3.5          6          AS6         Z
#
#    Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)
# 0                               8.5                           33
# 1                               9.6                           29
# 2                               5.9                           48
# 3                              11.1                           25
# 4                              10.6                           27

# %%
le_make=preprocessing.LabelEncoder()
le_make.fit(['ACURA', 'ALFA ROMEO', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW',
       'BUICK', 'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DODGE', 'FIAT',
       'FORD', 'GMC', 'HONDA', 'HYUNDAI', 'INFINITI', 'JAGUAR', 'JEEP',
       'KIA', 'LAMBORGHINI', 'LAND ROVER', 'LEXUS', 'LINCOLN', 'MASERATI',
       'MAZDA', 'MERCEDES-BENZ', 'MINI', 'MITSUBISHI', 'NISSAN',
       'PORSCHE', 'RAM', 'ROLLS-ROYCE', 'SCION', 'SMART', 'SRT', 'SUBARU',
       'TOYOTA', 'VOLKSWAGEN', 'VOLVO', 'GENESIS', 'BUGATTI'])
x.iloc[:,0]=le_make.transform(x.iloc[:,0])
le_fuel = preprocessing.LabelEncoder()
le_fuel.fit(['Z', 'D', 'X', 'E', 'N'])
x.iloc[:,5]=le_fuel.transform(x.iloc[:,5])
le_transmission = preprocessing.LabelEncoder()
le_transmission.fit(['AS5', 'M6', 'AV7', 'AS6', 'AM6', 'A6', 'AM7', 'AV8', 'AS8', 'A7',
       'A8', 'M7', 'A4', 'M5', 'AV', 'A5', 'AS7', 'A9', 'AS9', 'AV6',
       'AS4', 'AM5', 'AM8', 'AM9', 'AS10', 'A10', 'AV10'])
x.iloc[:,4]=le_transmission.transform(x.iloc[:,4])
le_class = preprocessing.LabelEncoder()
le_class.fit(['COMPACT', 'SUV - SMALL', 'MID-SIZE', 'TWO-SEATER', 'MINICOMPACT',
       'SUBCOMPACT', 'FULL-SIZE', 'STATION WAGON - SMALL',
       'SUV - STANDARD', 'VAN - CARGO', 'VAN - PASSENGER',
       'PICKUP TRUCK - STANDARD', 'MINIVAN', 'SPECIAL PURPOSE VEHICLE',
       'STATION WAGON - MID-SIZE', 'PICKUP TRUCK - SMALL'])
x.iloc[:,1]=le_class.transform(x.iloc[:,1])
# Out:
# c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
# adding bias colum
m=x.shape[0]
a=np.ones((m,1))
x.insert(0,"onces",a)

# %%
y=data[['CO2 Emissions(g/km)']]
y.head()
# Out:
#    CO2 Emissions(g/km)
# 0                  196
# 1                  221
# 2                  136
# 3                  255
# 4                  244

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=6)
print('Train set',x_train.shape,y_train.shape)
print('Test set',x_test.shape,y_test.shape)
# Out:
# Train set (6646, 9) (6646, 1)
# Test set (739, 9) (739, 1)

# %%
theta=gradientDesent(x_train,y_train,0.001,50000)

print(x.shape)
# Out:
# CO2 Emissions(g/km)    1.033168e+10
# dtype: float64
# CO2 Emissions(g/km)    9.055531e+09
# dtype: float64
# CO2 Emissions(g/km)    8.817784e+09
# dtype: float64
# CO2 Emissions(g/km)    8.642538e+09
# dtype: float64
# CO2 Emissions(g/km)    8.492645e+09
# dtype: float64
# CO2 Emissions(g/km)    8.363441e+09
# dtype: float64
# CO2 Emissions(g/km)    8.251908e+09
# dtype: float64
# CO2 Emissions(g/km)    8.155521e+09
# dtype: float64
# CO2 Emissions(g/km)    8.072139e+09
# dtype: float64
# CO2 Emissions(g/km)    7.999939e+09
# dtype: float64
# CO2 Emissions(g/km)    7.937368e+09
# dtype: float64
# CO2 Emissions(g/km)    7.883096e+09
# dtype: float64
# CO2 Emissions(g/km)    7.835987e+09
# dtype: float64
# CO2 Emissions(g/km)    7.795066e+09
# dtype: float64
# CO2 Emissions(g/km)    7.759495e+09
# dtype: float64
# CO2 Emissions(g/km)    7.728553e+09
# dtype: float64
# CO2 Emissions(g/km)    7.701621e+09
# dtype: float64
# CO2 Emissions(g/km)    7.678163e+09
# dtype: float64
# ...

# %%
from sklearn.metrics import r2_score

y_predict_train=predict(x_train,theta)
y_predict_test=predict(x_test,theta)

print('accuracy of traning set: %.2f' % r2_score(y_predict_train, y_train))



print('accuracy of testing set: %.2f' % r2_score(y_predict_test, y_test))
# Out:
# accuracy of traning set: 0.90
# accuracy of testing set: 0.90
